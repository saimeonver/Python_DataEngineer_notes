# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/12_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_dict = {'name': 'Saime', 'gender': 'Female', 'Age': 33}

# %%
my_dict['gender']
# Out:
# 'Female'

# %%
my_dict
# Out:
# {'name': 'Saime', 'gender': 'Female', 'Age': 33}

# %%
my_dict['Age']= 30

# %%
my_dict
# Out:
# {'name': 'Saime', 'gender': 'Female', 'Age': 30}

# %%
my_dict['city'] = 'istanbul'

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'gender', 'Age', 'city'])

# %%
my_dict.values()
# Out:
# dict_values(['Saime', 'Female', 30, 'istanbul'])

# %%
my_dict.items()
# Out:
# dict_items([('name', 'Saime'), ('gender', 'Female'), ('Age', 30), ('city', 'istanbul')])

# %%
for i in my_dict.items():
  print(i)
# Out:
# ('name', 'Saime')
# ('gender', 'Female')
# ('Age', 30)
# ('city', 'istanbul')

# %%
for i in my_dict.keys():
  print(i)
# Out:
# name
# gender
# Age
# city

# %%
for i in my_dict:
  print(i)
# Out:
# name
# gender
# Age
# city

# %%
my_dict.get('name')
# Out:
# 'Saime'

# %%
my_dict.update({'name': "Ayşe", "Age": "32"})

# %%
my_dict
# Out:
# {'name': 'Ayşe', 'gender': 'Female', 'Age': '32', 'city': 'istanbul'}
