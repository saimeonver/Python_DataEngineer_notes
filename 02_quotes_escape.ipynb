# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/02_quotes_escape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Normal usage")
# Out:
# Normal usage

# %%
print("Ankara'da")
# Out:
# Ankara'da

# %%
print('Normal usage')
# Out:
# Normal usage

# %%
print('Ankara'da')
# Out:
#   File "/tmp/ipykernel_538/2286831975.py", line 1
#     print('Ankara'da')
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Ankara\'da')
# Out:
# Ankara'da

# %%
print("""Ankara' da""")
# Out:
# Ankara' da

# %%
print("First line \
Second line \
Third line  \
")
# Out:
# First line Second line Third line

# %%
my_path = "c:\\documents\\myfolder"

# %%
print(my_path)
# Out:
# c:\documents\myfolder
