# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/04_print_format.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
domain_name = "datalonga"
top_domain = "com"

# %%
print("I have just bought {}.{}".format(domain_name,top_domain))
# Out:
# I have just bought datalonga.com

# %%
print(f"I have just bought {domain_name}.{top_domain}")
# Out:
# I have just bought datalonga.com

# %%
print("I have just bought %s.%s" %(domain_name, top_domain))
# Out:
# I have just bought datalonga.com
