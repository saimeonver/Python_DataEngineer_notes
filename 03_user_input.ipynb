# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/03_user_input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Name:")
# Out:
# Name:saime

# %%
name
# Out:
# 'saime'

# %%
age = int(input("Age:"))
# Out:
# Age:33

# %%
age
# Out:
# 33

# %%
type(age)
# Out:
# int
