# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/14_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def my_function(p1:int, p2:str):


  return x

# %%
def my_function2(p1 = 1, p2 = 'Ankara'):

  return p1

# %%
my_function2()
# Out:
# 1

# %%
my_function2(p2='Sinop')
# Out:
# 1

# %%
my_function2(p1=4) #argümanlar parametreler atanan değerlerdir
# Out:
# 4

# %%
#parametre ön tanımlı ise ve ön tanımlı olmayan başka parametreler varsa önce tanımlı olmayanlar yazılır aşağıdaki gibi

# %%
def my_function3(p2,p1=1):

  return p2

# %%
my_function3(5)
# Out:
# 5

# %%
my_function3("Sinop")
# Out:
# 'Sinop'

# %%
#belirsiz parameterlerde

def my_function4(*args):

  return args[2]

# %%
my_function4(1,2,3,4)
# Out:
# 3

# %%
def my_function5(**kwargs):

  name = kwargs['name'] + ' ' + kwargs['surname']

  return name

# %%
my_function5(**{'name': 'Saime', 'surname': 'ÖNVER', 'age': 33})
# Out:
# 'Saime ÖNVER'

# %% [markdown]
# Değer dönmeden iş yaptırabiliriz. illa return ile döndürmemize gerek yok

# %%
def my_function5(**kwargs):

  name = kwargs['name'] + ' ' + kwargs['surname']

  print(name)
