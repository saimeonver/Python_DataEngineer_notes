# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# %%
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'

# %% [markdown]
# working directory

# %%
import os
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# Indentations

# %%
if 2 > 1 :
  print("It is true")
# Out:
# It is true

# %%
if 2 > 1 :
print("Is is wrong")
# Out:
#   File "/tmp/ipykernel_332/1798194931.py", line 2
#     print("Is is wrong")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# Comment

# %%
#This is comment
a = 5

# %%
"""
This is block comment
"""
b= 5

# %%
'''
This is also block comment
'''
c = 5
