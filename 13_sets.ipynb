# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/13_sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_set = set() #küme mantığında çalışıyor. aynı elemandan birden fazla olmaz

# %%
type(my_set)
# Out:
# set

# %%
py_list = [1,1,2,2,3,4,5,6,6,7]

# %%
py_set = set(py_list)

# %%
py_set
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
py_set.add(8)

# %%
py_set
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
py_set2 = py_set.copy()

# %%
py_set2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
py_set.add(9)

# %%
py_set
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
py_set2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
py_set.intersection(py_set2) #kesişim
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
py_set.union(py_set2) #birleşim
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
py_set.difference(py_set2) #fark
# Out:
# {9}
