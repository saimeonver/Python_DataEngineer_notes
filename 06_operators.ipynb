# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/06_operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5+6
# Out:
# 11

# %%
4-2
# Out:
# 2

# %%
4/2
# Out:
# 2.0

# %%
2*5
# Out:
# 10

# %%
2**3
# Out:
# 8

# %%
7%2
# Out:
# 1

# %%
8%2
# Out:
# 0

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
8//3
# Out:
# 2

# %%
8/3
# Out:
# 2.6666666666666665

# %%
"Hello" +" " + "dataops"
# Out:
# 'Hello dataops'

# %%
'2'+'4'
# Out:
# '24'

# %%
"-"*10
# Out:
# '----------'

# %%
7==6
# Out:
# False

# %%
5==5
# Out:
# True

# %%
5>4
# Out:
# True

# %%
5>6
# Out:
# False

# %%
5>5
# Out:
# False

# %%
5>=5
# Out:
# True

# %%
"ali" == "ali"
# Out:
# True

# %%
"Ali" == "ali"
# Out:
# False

# %%
a = 77

# %%
a += 5

# %%
a
# Out:
# 82

# %%
names = ["Ali", "Mehtap", "Şengül", "Soykan"]

# %%
"Mehmet" in names
# Out:
# False

# %%
"Ali" in names
# Out:
# True
