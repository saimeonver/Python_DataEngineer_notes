# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/01_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 5

# %%
a = "ali"

# %%
a
# Out:
# 'ali'

# %%
type(a)
# Out:
# str

# %%
a = 22

# %%
type(a)
# Out:
# int

# %%
a_b = 2

# %%
2aa= 5
# Out:
#   File "/tmp/ipykernel_1087/736439002.py", line 1
#     2aa= 5
#     ^
# SyntaxError: invalid decimal literal

# %%
ab = 3
AB= 5

# %%
ab
# Out:
# 3

# %%
AB
# Out:
# 5

# %%
import  keyword
keyword.kwlist
#aşağıda listelenen isimleri değişken adı olarak kullanamazsın
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
a = b = 5

# %%
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
[a,b,c]=[1,6,"Malatya"]

# %%
c
# Out:
# 'Malatya'

# %%
a , b, c = 12, 13, "Konya"

# %%
c
# Out:
# 'Konya'

# %%
5 * 6
# Out:
# 30

# %%
_
# Out:
# 30

# %%
# _ her zaman en son çıktıyı veriyor
