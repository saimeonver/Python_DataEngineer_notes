# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/10_list_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
my_list = [1,2,3]

# %%
my_list.append(4)

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list.extend([5,6])

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
my_list += [7,8]

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
my_list.insert(0,0)

# %%
my_list
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
my_list.insert(2,1.5)

# %%
my_list
# Out:
# [0, 1, 1.5, 2, 3, 4, 5, 6, 7, 8]

# %%
my_list.remove(1.5)

# %%
my_list
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
my_list.append(2)

# %%
my_list
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8, 2]

# %%
my_list.remove(2)

# %%
my_list
# Out:
# [0, 1, 3, 4, 5, 6, 7, 8, 2]

# %%
my_list.reverse()

# %%
my_list
# Out:
# [2, 8, 7, 6, 5, 4, 3, 1, 0]

# %%
my_list.pop(2)#paranetes için indexi verir . değer girmerzsen son değeri siler
# Out:
# 7

# %%
my_list
# Out:
# [2, 8, 6, 5, 4, 3, 1, 0]

# %%
my_list.sort()#küçükten büyüğe sıraladı

# %%
my_list
# Out:
# [0, 1, 2, 3, 4, 5, 6, 8]

# %%
my_list.insert(7,7)

# %%
my_list
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
my_list.count(2)
# Out:
# 1

# %%
my_list.extend([2,2,2,2,2,3,3,3,3,3,4,4])

# %%
my_list.count(2)
# Out:
# 6

# %%
my_list.count(4)
# Out:
# 3

# %%
my_list.clear()

# %%
my_list
# Out:
# []
