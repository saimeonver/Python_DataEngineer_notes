# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/05_conditionals_if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""if condition:
  do something
elif other_condition:
  do elif things
else:
  do something else"""

# %%
number = -7

# %%
if number > 0:
  print(f"{number} is positive")
elif number == 0:
  print(f"{number} is zero")
else:
  print(f"{number} is negative")
# Out:
# -7 is negative
