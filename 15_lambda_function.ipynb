# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/15_lambda_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
summer = lambda x, y : x +y

# %%
summer(1,3)
# Out:
# 4

# %%
odd_or_even = lambda x : 'odd' if x % 2 == 1 else  'even'

# %%
odd_or_even(4)
# Out:
# 'even'

# %%
odd_or_even(7)
# Out:
# 'odd'
