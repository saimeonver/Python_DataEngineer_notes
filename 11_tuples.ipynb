# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/11_tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tuple1 = ("elma", "kiraz", "armut")

# %%
type(tuple1)
# Out:
# tuple

# %%
python_liste = ["Muz","Erik", 7.8, 5.5]
tuple4 = tuple(python_liste)

# %%
tuple4
# Out:
# ('Muz', 'Erik', 7.8, 5.5)

# %%
#yukarıdaki örnekte listeden tuple a çevirdik

# %%
tuple6 = ("Vişne")

# %%
type(tuple6)
# Out:
# str

# %%
tuple7= ("Vişne",)

# %%
type(tuple7)
# Out:
# tuple

# %%
tuple4[0]
# Out:
# 'Muz'

# %%
tuple4[-1]
# Out:
# 5.5

# %%
python_liste[-1]=6.5

# %%
python_liste
# Out:
# ['Muz', 'Erik', 7.8, 6.5]

# %%
tuple4[-1] =6.5 #listeden farklı olarak tuple da eleman değiştirilemez
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_683/3737961645.py in <cell line: 0>()
# ----> 1 tuple4[-1] =6.5
#
# TypeError: 'tuple' object does not support item assignment
