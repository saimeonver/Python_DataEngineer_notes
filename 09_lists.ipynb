# %% [markdown]
# <a href="https://colab.research.google.com/github/saimeonver/Python_DataEngineer_notes/blob/main/9_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number_list = [1,6,88,12,5]

# %%
type(number_list)
# Out:
# list

# %%
character_list = ["İstanbul","Ankara","Sinop"]

# %%
mixed_list = [1,6,88,"İstanbul","Ankara","Sinop"]

# %%
number_list[1:3]
# Out:
# [6, 88]

# %%
number_list[-1]
# Out:
# 5

# %%
number_list[-2]
# Out:
# 12

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
number_list.append(100)

# %%
number_list
# Out:
# [1, 6, 88, 12, 5, 100]

# %%
number_list.extend(mixed_list)

# %%
number_list
# Out:
# [1, 6, 88, 12, 5, 100, 1, 6, 88, 'İstanbul', 'Ankara', 'Sinop']

# %%
del(number_list[-1])

# %%
number_list
# Out:
# [1, 6, 88, 12, 5, 100, 1, 6, 88, 'İstanbul', 'Ankara']
